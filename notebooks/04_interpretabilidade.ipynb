# %% [markdown]
# # 04 — Interpretabilidade e perfis
# SHAP, importância por permutação, coeficientes e clusterização exploratória.

# %%
from pathlib import Path
import pandas as pd
ROOT=Path.cwd()
pd.read_csv(ROOT/'reports'/'shap_importancia_modelo_aluno.csv').head(15)
# Out:
#                     feature_transformada  mean_abs_shap
# 0      num__media_portugues_2023_publica       0.466675
# 1                             cat__uf_GO       0.200019
# 2                             cat__uf_BA       0.104230
# 3                             cat__uf_RS       0.103180
# 4   num__taxa_alfabetizacao_2023_publica       0.078309
# 5           num__meta_alfabetizacao_2024       0.063064
# 6                             cat__uf_MS       0.037656
# 7                             cat__uf_AL       0.012358
# 8                             cat__uf_MT       0.008491
# 9                             cat__uf_SC       0.005594
# 10                            cat__uf_SE       0.004947
# 11                           cat__rede_2       0.003765
# 12                           cat__rede_3       0.000926
# 13                            cat__uf_DF       0.000000

# %%
pd.read_csv(ROOT/'reports'/'coeficientes_modelo_municipal.csv').head(15)
# Out:
#          feature_transformada  coeficiente  abs_coeficiente
# 0                  cat__uf_BA     2.415753         2.415753
# 1                  cat__uf_GO    -2.104531         2.104531
# 2                  cat__uf_CE    -1.963618         1.963618
# 3              num__meta_alvo     1.894568         1.894568
# 4                  cat__uf_ES    -1.851381         1.851381
# 5                  cat__uf_RS     1.622120         1.622120
# 6                  cat__uf_MG    -1.529216         1.529216
# 7                  cat__uf_AM     1.291141         1.291141
# 8                  cat__uf_SE     1.060428         1.060428
# 9                  cat__uf_PA     1.019892         1.019892
# 10                 cat__uf_RN     0.949390         0.949390
# 11                 cat__uf_AP     0.902719         0.902719
# 12  num__media_portugues_base    -0.845697         0.845697
# 13                 cat__uf_SC    -0.803199         0.803199
# 14                 cat__uf_PR    -0.683120         0.683120

# %%
pd.read_csv(ROOT/'reports'/'centroides_clusters_2025.csv')
# Out:
#    cluster  ...                         perfil_cluster
# 0        1  ...        Melhor desempenho / menor risco
# 1        3  ...                   Desempenho favorável
# 2        0  ...  Pressão de meta / risco intermediário
# 3        2  ...    Maior vulnerabilidade / maior risco
#
# [4 rows x 7 columns]
